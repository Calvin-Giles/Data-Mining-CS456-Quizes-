# %% [markdown]
# # Read Damaged Data

# %% [markdown]
# Data interpretation varies with format, necessitating organization into dataframes for machine readability. This step transforms diverse data into a structured, table-like format, facilitating manipulation and analysis. It's crucial for identifying trends and ensuring data quality, thus setting the foundation for subsequent analytical and predictive tasks in a unified, efficient manner.

# %%
import os
os.listdir()
# Out:
# ['CBcmkyZ8v4tAc8PSDcEgvM-1200-80.jpg',
#  'Anaconda3-2020.11-MacOSX-x86_64.pkg',
#  'Lecture 6 Supply and Demand.docx',
#  'www.google.com.exe',
#  'Discord.dmg',
#  'CS312_Lab1.docx',
#  'M330-Num1R-HWP01-Template.pdf',
#  'Assignment 9.docx',
#  'Lex Fridman #72 notes and response.docx',
#  'googlechrome.dmg',
#  'damaged_students.csv',
#  'Grading Commentary United-1.pdf',
#  'damaged.json',
#  'Giles_Annotated Bibliography; CS325 (2).zip',
#  'ArithmeticOperators.class',
#  'Screen Shot 2023-02-13 at 12.50.28 PM.png',
#  'M330-Num4R-HWP01-Template.docx',
#  'macOS_VCP_Driver',
#  'BST$Node.class',
#  '~$dterm Study Guide Winter 2022.docx',
#  'Visual Studio Code.app',
#  'Lecture 4 The Macroeconomic Model.docx',
#  'Survey of Lit Rough Draft - Dean Yockey.docx',
#  'BST.class',
#  'seamless-paper-texture-business-card-background.jpg',
#  '0133971287_PPT',
#  'Annotated Bibliography; CS325 (1).zip',
#  'FINAL VISUAL Project Student Model.pptx',
#  'TI84PlusSE.rom',
#  '260 - Day 11 - Section 2.3.pdf',
#  'Lab1.class',
#  'Calvin Giles Results.pdf',
#  'CMST101_Jo_Hari_Window.pptx',
#  'Summ2RDrLaw (1).docx',
#  'Chapter2_CommunicationInTheRealWorld.pdf',
#  'Chapter 15-Media Effects-1.pptx',
#  'Lab 5 Summary and Explanation (1).docx',
#  'Bobbie 2022_TaxReturn.pdf',
#  'Lab3 (1).docx',
#  'ds11_pdf-3.PDF',
#  'Assignment 3 .xlsx',
#  'Assignment 5.docx',
#  'CS112 Project.docx',
#  'Homework 5.docx',
#  'VSCode-darwin-universal (1).zip',
#  'W-2 2021.pdf',
#  'mathematics-11-03423.pdf',
#  '~$380+Exam+2+Study+Guide.docx',
#  'openjdk-21.0.1_macos-aarch64_bin.tar.gz',
#  'Copart Odometer Statement.pdf',
#  'Complete the codes by fixing errors (7).pdf',
#  'Giles_Annotated Bibliography; CS325 (2)',
#  '260 - Day 16 - Section 3.1.pdf',
#  'Week Three Class Notes.pptx',
#  'Calvin+Giles+Resume.pdf',
#  'Lab6$numberComparator.class',
#  'IPv4 Network Address Finding Exercises (1).docx',
#  '~$Two-link Practice.xlsx',
#  'Chap_05_Ex02.pdf',
#  "Moore's magical realism-1 - Tagged.pdf",
#  'Security Plus SY0-701 Domain 1 Handout.pdf',
#  '~$cture 6 Supply and Demand (1).docx',
#  'mysql-workbench-community-8.0.40-macos-arm64.dmg',
#  'TimeSumalationExample.java',
#  'Functions.pdf',
#  '2024-25 CWU and CS Important Policies.pdf',
#  'ds11_pdf-2.PDF',
#  'AvoidingSexistLanguage.pdf',
#  'M330-Num2R-HWP01-Template.pdf',
#  'lysted-remit-8cd11e1c9e.csv',
#  'Lecture 7 Businesses Competition.docx',
#  'R1-HWP02-SavingsLoans-Template.pdf',
#  'Bobbie 2021_TaxReturn.pdf',
#  '1611560242.357723.jpg',
#  'Essay One Sources ENGL&102.docx',
#  'Week 4 Written Homework.pdf',
#  'lab4-1.zip',
#  '.DS_Store',
#  'Test 1 3.pdf',
#  'us_tourism.csv',
#  'shyness by Susan Cain.docx',
#  'Test 1 2.pdf',
#  'tax1099nec-2021-acct_1IIqdrMBYD22b6Zm.pdf',
#  'VSCode-darwin-universal.zip.download',
#  '~$signment 2.docx',
#  'PHIL101 LRA - Online Class.doc',
#  '45855902_20231116101130.pdf',
#  'Complete the codes by fixing errors (6).pdf',
#  'Lab7.class',
#  'peer edit research essay 3.doc',
#  'Homework 4.docx',
#  'Assignment 4.docx',
#  '~$ Multiple Table Practice.docx',
#  'CS380 Exam 2 Study Guide.pdf',
#  'winhex',
#  'Lab 4 11.png',
#  'be1a2f1a-01dc-4a8e-ad1e-5d0935bb707b.pdf',
#  'SerializationExample.java',
#  'Week 1 Written Homework.pdf',
#  'Assignment 10.docx',
#  'Lab5$numberComparator.class',
#  'verified_fans.csv',
#  'Life Happens Coupon.docx',
#  'Final study guide.docx',
#  'Intro to Philo - W3.pdf',
#  'index.pdf',
#  'winhex.zip',
#  'Lab 4 13.png',
#  'What is it like to be a bat.pdf',
#  'Assignment 9 Answer Sheet.sql',
#  'Archive',
#  'Cole Giles.docx',
#  'MyGuitarShopTablesAndData.pdf',
#  'Robinhood1099.pdf',
#  'RA Multiple Table Practice.docx',
#  'assignment7',
#  'HTML CSS Chapter 1 thru 7 slides',
#  'ba4bf594-025b-4348-a3c9-518c18d58451.csv',
#  'ArrayProcessor.java',
#  'Lab5.class',
#  '5_1 (1).docx',
#  'Summ2RDrLaw.docx',
#  'Essay 1 ENGL&102.docx',
#  '260 - Day 17 - Section 3.1.pdf',
#  'The Norton Field Guide to Writing with Readings and Handbook by Richard Bullock, Maureen Daly Goggin, Francine Weinberg (z-lib.org).pdf',
#  'Test 1 1.pdf',
#  'CalculusVolume2-OP.pdf',
#  '~$380 Exam 1.docx',
#  '8cc90883-d489-4cf6-ad15-5b03b8ab0520.pptx',
#  'mathematics-11-03423 (1).pdf',
#  'Lab1$Node.class',
#  'mysql-utilities-1.6.5-macos10.12.dmg',
#  'Giles_Annotated Bibliography; CS325 (3).zip',
#  'html_css_student_download',
#  'Screen Shot 2022-07-27 at 12.34.06 PM.png',
#  '.localized',
#  'Assignment 8.docx',
#  'Lab8.java',
#  'course_files_export (1).zip',
#  'Lab 4 12.png',
#  'Works Cited Hum 215 2021.docx',
#  'ScreencastOMaticSetup-2.21.1-JRE14.dmg',
#  'Chapter 1 video (Part 2).webm',
#  'Philosophy Somebody-1 (1).pptx',
#  'Annotated Bibliography CS325 Updated (2).zip',
#  'Project Proposal .docx',
#  'true-2.html',
#  'Assignment 3.docx',
#  'Nobel Lecture by Toni Morrison.pdf',
#  'IMG_3953 (1).HEIC',
#  'HW quiz 3.pdf',
#  'Homework 3.docx',
#  'web.zip',
#  '~$mmary Notes.docx',
#  'Complete the codes by fixing errors (1).pdf',
#  'ds11_pdf.PDF',
#  'cs110 lectures',
#  'Stafford Indian Cinema.pdf',
#  'Lab2.class',
#  '96245a5fa17079be998e7b4fd2d3c8ef.jpg',
#  '0133971287_PPT 2',
#  'Lab6$Node.class',
#  'ed8f1257-42c6-4f65-a9e5-9e2454c6d2f6_a320c255-2788-4f73-8a82-c4f383ffad48.pdf',
#  'Archive 2.zip',
#  'bin.zip',
#  '~$nal study guide.docx',
#  'serving-web-content.zip',
#  'Lecture 4 Fiscal Policy.docx',
#  '2023_TaxReturn.pdf',
#  'conceptPortfolioSetOne.pptx',
#  '5_1.docx',
#  'course_files_export.zip',
#  'blender-3.3.1-macos-arm64.dmg',
#  'FinalA.docx',
#  'lysted-fchat_2023_02_24_393239201_07b88d2280..jpeg',
#  '15UnionFind (1).pdf',
#  '260 - Day 13 - Section 2.3.pdf',
#  'Philolaus Pamphlet.pdf',
#  'Graph.java',
#  'Receipt-2688-0244.pdf',
#  'Two-link Practice.xlsx',
#  'Full Portfolio - Sample 1 - Calc 3.pdf',
#  'concept portfolio.pptx',
#  '7th_edition_PowerPoint slides (1).zip',
#  'Wrapping Up Cyberwarfare.docx',
#  'VF_SIGN_UP.csv',
#  'lysted-remit-3d79468388.csv',
#  'chapt 28 20180125142817472.pdf',
#  'Lab 4 3.png',
#  'Chapter 2 videos.docx',
#  'Proposal, Types of Evidence, questionnaire.docx',
#  'Annotated Bibliography CS325 Updated (3)',
#  'Plautus-main.zip',
#  'Self-Concept Research Paper.docx',
#  'Mastery Grading Checklist Winter 2021.pdf',
#  'ReviewerChecklist AnnotBib Codes (1).docx',
#  'Calvin Giles_Quiz22.ipynb',
#  'Theconsequencesoflackofcybersecurityeducationinhighschoolaglobalperspective.pdf',
#  'Assignment 9 (1).docx',
#  'CMST101_Course Overview.pdf',
#  'Giles_Annotated Bibliography; CS325 (4).zip',
#  'DocumentsPdf-2.pdf',
#  'MATH 151 online syllabus Fall 21.docx',
#  'algs4.jar',
#  'Lab 2.docx',
#  'IT_Software_Intern_Resume_Final.docx',
#  'critical-theory-today.pdf',
#  'Email_Headers-1.docx',
#  'TheFrenchNewWave_Nottingham.pdf',
#  'CC_ADDER_DATABASE.xlsx',
#  'SSF_SS_1098T.pdf',
#  'CS312Lab 3.zip',
#  'DocumentsPdf-3.pdf',
#  'Graphics_Stego (1).docx',
#  'Giles Calvin_Spring.pdf',
#  'Lecture 3 Business Cycle and Unemployment.html',
#  'Assignment6a.docx',
#  'sklearn_irisdata_logisticregression_decisiontree (1).ipynb',
#  'Lecture #14 - Algebraic Expressions.pdf',
#  'lysted-fchat_2023_02_24_394130598_8e6a3d67c5..jpeg',
#  'Concept portfolio problem sets 1 & 2.pptx',
#  'M4 238 Hybrid Spring 2024 S.pptx',
#  'Essay #3 draft.docx',
#  'Lab 4 2.png',
#  'Week Two Class Notes.docx',
#  'Lab 4 6.png',
#  'HW quiz 2 p2.pdf',
#  'ESP32 Basic Starter Kit.pdf',
#  'Annotated_Bibliography__CS325 (2).pdf',
#  'Italian Neorealism-2-2.pdf',
#  'annotated-Summ2RDrGiles.docx.pdf',
#  'bibtemp-3.bib',
#  'Code',
#  'us_tourism2damage-1.csv',
#  '~$_Software_Intern_Resume.docx',
#  'Summ2RDrGiles Reviewed (1).docx',
#  'Television.pptx',
#  's11831-022-09732-9.pdf',
#  'conceptPortfolioProblemSetTwo.pptx',
#  'Final REI Personnel Privacy Notice_v2.pdf',
#  'Third Cinema as Guardian of Popular Memory.doc',
#  'Lecture 1 Macroeconomic Goals and the History of Economic Thought.docx',
#  'Giles_Annotated_Bibliography__CS325 (1).pdf',
#  'Annotated Bibliography CS325 Updated.zip',
#  'Eng102EssayResponse.docx',
#  'Lunch atop a Skyscraper Essay 2.docx',
#  's11831-022-09732-9 (1).pdf',
#  'Chapter1_CommunicationInTheRealWorld.pdf',
#  'Chapter 4-Sound Recording and Popular Music-6.ppt',
#  'What Is Magical Realism.docx',
#  'Assignment 3.zip',
#  'Math&152 Week 1 Written Homework .docx',
#  'Italian Neorealism-2-3.pdf',
#  '_tmp__lease_documents_20231127125501.pdf',
#  'IMG_3953.HEIC',
#  '260 - Day 21 - Section 3.2.pdf',
#  'Grammarly.s31Qbfb9znec7n45m0320c02.dmg',
#  'Calvin+Giles+country_with_index.csv',
#  'Lab 4 7.png',
#  'CS380 Exam2-1.docx',
#  'problem set 2.pdf',
#  'Lab 4 5.png',
#  'Invoice-491BEA75-0001.pdf',
#  'e85b80c2-2761-406f-a958-63b1ed8817d6.pdf',
#  'dataset for exercises.zip',
#  'Lecture 6 Supply and Demand.docx.download',
#  'company_db_schema.pdf',
#  'Practice #3 - Lines and Planes in 3D.pdf',
#  'DocumentsPdf-4.pdf',
#  'ideaIC-2023.1-aarch64.dmg',
#  'Intro to Philo - W2 .pdf',
#  'MAMP-MAMP-PRO-Downloader.zip',
#  'ICEEE RequirementsSoftwareSpec.pdf',
#  'Chapter4_CommunicationInTheRealWorld.pdf',
#  'WorkLifeMatters - Employee Overview.pdf',
#  'Norton Field Guide to Writing with Readings and Handbook.pdf',
#  'Lab Summ1RoughDr H_Sheikh.docx',
#  'Cats and Dogs_Windows Forensics.docx',
#  'Homework 2.docx',
#  'Week 1 - HW Solutions.pdf',
#  'bibtemp-1.bib',
#  '325383-sdm-vol-2abcd.pdf',
#  'Lab2.java',
#  'Lab6.class',
#  'Assignment 2 Practice.docx',
#  'true-3.html',
#  '5_1 (2).docx',
#  'Assignment 2.docx',
#  'true.json',
#  'Lab 2_Hash__Skills_Lab-3.docx',
#  'lysted-remit-10b3414e5e (1).csv',
#  'Lab Assignment #4 (1).pdf',
#  'Annotated Bibliography CS325 Updated (3).zip',
#  'Lab 4 4.png',
#  'Lab 9 - VM_Forensics.docx',
#  'Response Prompt.docx',
#  'Lab 4 9.png',
#  'Midterm Study Guide Winter 2022.docx',
#  '260 - Day 19 - Section 3.2.pdf',
#  'assignment7.zip',
#  'Lab 8 4.png',
#  's40507-021-00114-x.pdf',
#  'Giles_Annotated Bibliography; CS325 (4)',
#  'Giles_Annotated_Bibliography__CS325.pdf',
#  'lab5_1.asm',
#  'Class Registration Form.docx',
#  'Annotated Bibliography; CS325.zip',
#  'PokemonTCG_EmptyCheckList_v9.0.xlsm',
#  'Italian Neorealism-2.pdf',
#  'Lab Assignment #2.pdf',
#  'true.html',
#  'UPS_label.png',
#  'Peer Review Worksheet [typed responses].docx',
#  'Annotated Bibliography CS325 Updated (2) 2',
#  'Presentation1.pdf',
#  'Complete the codes by fixing errors (3).pdf',
#  'conceptPortfolioReflection.docx',
#  'PracticeMidterm.class',
#  'town_hall_1',
#  'Quote Sandwich.docx',
#  'CS311- Computer Architecture I -- Syllabus Fall 2024.pdf',
#  'Buffalo Soldiers.docx',
#  'UnityHubSetup.dmg',
#  'Lecture 6 Supply and Demand (1).docx',
#  'Assignment 1.docx',
#  'Guardian Book for WA Employees.pdf',
#  'Heap.java',
#  'Assignment 6b (1).docx',
#  'hourly-schedule-template-16.doc',
#  'Inventory_UML.png',
#  'Lab 4 8.png',
#  'mysql-connector-j-8.0.33.jar',
#  'Annotated_Bibliography__CS325 (1).pdf',
#  'Safeco TL16_Power of Attorney Notarized.pdf',
#  'F1U2P2_solution',
#  'Logic1.lgi',
#  'Deleted Data Using Autopsy.doc',
#  'IT_Software_Intern_Resume.docx',
#  'SSF_SS_1098T-3.pdf',
#  'create_my_guitar_shop.sql',
#  'Popular Culture 2.pptx',
#  'Week 9 Written Homework.pdf',
#  'Calvin.pdf',
#  'Area.java',
#  'Service Learning Reflection.docx',
#  'CS301 Data Structures Syllabus - Fall 2024.pdf',
#  'MinHeap.class',
#  '938ddfac-3989-4a7d-a909-a07dca51a39a.pdf',
#  'nut text pg#s (1).pdf',
#  'Graphics_Stego.docx',
#  'Normal Forms Handout.pdf',
#  'SSF_SS_1098T-2.pdf',
#  'week4 hw quiz 1-1.pdf',
#  'Firefox 118.0.2.dmg',
#  'MATH151Syllabusspring2021.docx',
#  'Textual Summary ENGL&102.docx',
#  'What Is Magical Realism - Tagged.pdf',
#  '9e14d89e-d536-489d-ba4a-46c48301bd79.csv',
#  'gdp1q21_adv.xlsx',
#  'RobloxStudio.dmg',
#  'IT_Software_Intern_Resume_Styled.docx',
#  'simpleEncrypt.java',
#  'eclipse-inst-jre-mac-aarch64.dmg',
#  '2023-24-bs-cyber-advising-ge.xlsx',
#  'Annotated Bibliography CS325 Updated (2)',
#  'CS112 Project-1.docx',
#  '7th_edition_PowerPoint slides.zip',
#  '~$cture 2 GDP-2.docx',
#  '9B034BBC-9003-4D75-B63A-FBAEDC382FA9.heic',
#  'Lab 4.1 - Windows Registry_Updated-1 (1).docx',
#  'DamagedDataRead.ipynb',
#  'SurveyLitRD.docx',
#  'SurveyLitRD - Calvin Giles.docx',
#  'openstego-0.8.6',
#  'Lab 8 2.png',
#  'Class Registration Form Solution.docx',
#  'SSF_SS_1098T-6.pdf',
#  'Logic4.lgi',
#  'Softw Pract Exp - 2021 - Gill - Quantum computing  A taxonomy  systematic review and future directions.pdf',
#  'CS380 Exam 1.docx',
#  'town_hall_1.zip',
#  'conceptPortfolioFinale.pptx',
#  'Chapter5_CommunicationInTheRealWorld.pdf',
#  'NTML_CSS_student_download.zip',
#  'Logical Arguments.docx',
#  'ReviewerChecklist AnnotBib Codes.docx',
#  'Lab Assignment #4.pdf',
#  'articles.pdf',
#  'CIS121 Syllabus Fall 2022 C Bloomer.docx.download',
#  'Philosophical Somebody Project.docx',
#  'How To_DECLARE OR DROP A MAJOR OR MINOR (1) (1).pdf',
#  'PokemonTCGLiveInstaller_Mac.dmg',
#  'Assignment2',
#  'hashtest1.txt',
#  'Peer Review Worksheet [typed responses] (3).docx',
#  'Lab 8 3.png',
#  'iHealth Test-Mar 15, 2022 11_03_26 PM.png',
#  'Main.java',
#  'Lab Assignment #8-1.pdf',
#  '~$SQP1.doc',
#  '~$leted Data Using Autopsy.doc',
#  'State of DeFi Guest lecture.pdf',
#  'Calvin (1).pdf',
#  'essay 1 introversion F16.docx',
#  'openstego-0.8.6.zip',
#  'Day1.pdf',
#  'Pronouns Exercise (1).pdf',
#  'Annotated Bibliography CS325 Updated (1).zip',
#  'Complete the codes by fixing errors.pdf',
#  'Peer Review Worksheet [typed responses] (1).docx',
#  'Chapter7Shorter_CommunicationInTheRealWorld.pdf',
#  '15UnionFind.pdf',
#  'SSF_SS_1098T(1).pdf',
#  'Annotated Bibliography CS325 Updated (1)',
#  'Assignment2.zip',
#  'Norton Field Guide to Writing with Readings and Handbook-2.pdf',
#  'Decision Fatigue by John Tierney.docx',
#  'jdk-21.0.1.jdk',
#  'Lab 8 1.png',
#  'SSF_SS_1098T-5.pdf',
#  'Numpy and Pandas review (1).ipynb',
#  'apache-maven-3.9.9',
#  'Syllabus24Fall325.pdf',
#  'Zoom.pkg',
#  'Complete the codes by fixing errors (2).pdf',
#  'Lab_3_Date_Time_Stamp_Lab-1.docx',
#  'Lecture 2 GDP-2.docx',
#  'Week One Class Notes.docx',
#  '~$sayOneSources ENGL&102.docx',
#  'Presentation (1).pptx',
#  'Cinema Novo.docx',
#  'f6421306-37ba-4451-9b2d-56c3318db228.pdf',
#  'TurboTaxReturn.tax2022',
#  'Data_Science_recap.pdf',
#  'companyDB_build.sql',
#  'CMST101_Perceptual Process.pptx',
#  'M7 238 Hybrid Spring 2024 S.pptx',
#  'SSF_SS_1098T-4.pdf',
#  'Telegram.dmg',
#  'Packet_Tracer822_setup_mac_signed.dmg',
#  'PracticeMidterm.java',
#  'Lab 5 Summary and Explanation.docx',
#  'Ramez_Elmasri_Shamkant_B._Navathe_-_Fundamentals_of_Database_Systems-Pearson_2015.pdf',
#  'damaged_data.txt',
#  'python-3.9.0-macosx10.9.pkg',
#  'Grading Commentary United-1 (1).pdf',
#  'Chapter14_CommunicationInTheRealWorld.pdf',
#  '.ipynb_checkpoints',
#  '45855903_20231116101130.pdf',
#  '5707d308-8d4f-42be-8bdd-f4433ce1d3ef.pptx',
#  'Chapter6_CommunicationInTheRealWorld.pdf',
#  'Assignment 6b (2).docx',
#  'LabSumm1RoughDraft PeerReviw H_Sheikh.docx',
#  'Lab3.docx',
#  'Chapter 7-Movies and the Impact of Images-1-5.ppt',
#  '~$_Software_Intern_Resume_Styled.docx',
#  'Virtual_Box_Kali_SETUP PROCEDURES-1.pdf',
#  'addendum_template_304406_17453784_20240814053425_481115480.pdf',
#  'HTML CSS Chapter 1 thru 7 slides.zip',
#  '~$signment 10.docx',
#  '00Intro.pdf',
#  'form-RESIDENCY-Review-Checklist-July-11-2019.docx',
#  'robinhood2025Season.pdf',
#  'OUR Winter Grant Flyer.png',
#  'Trip to the City.pdf',
#  'Math330Workbook.pdf',
#  'Midterm Sample Problems Solutions.pdf',
#  'lysted-remit-10b3414e5e.csv',
#  'Calvin+Giles+country_no_index.csv',
#  'CS380+Exam+2+Study+Guide.docx',
#  'PrinciplesYou Reflection Exercise.pdf',
#  'LAB 4.png',
#  'Eng 102 Essay 3.docx',
#  '2ce2fb51-ebf2-4dc1-8319-a7af4793cf09.pdf',
#  'MAMP & MAMP PRO Downloader.app',
#  'Chapter 7-Movies and the Impact of Images-1-5 (1).ppt',
#  'lab4.zip',
#  'Mac_OSX_VCP_Driver.zip',
#  'Nagib Towards a positive definition of World Cinema.pdf',
#  'Intel_Intern_Slides_02262025.pptx',
#  'Magical Realism class notes.docx',
#  'Lecture 8 Market Failures.docx',
#  'registers.asm',
#  'Exam2ReviewDay_Spring20.pptx',
#  'SceneBuilder-23.0.1-aarch64.dmg',
#  'Lecture 1 Economic Goals and the Role of Government.docx',
#  'InstallLDBPackage64c-2-1-2-02.zip',
#  'Wrapping Up Cyberwarfare.pdf',
#  'Essay Outline Template(2).docx',
#  '~$cture 1 Economic Goals and the Role of Government.docx',
#  'image-2.png',
#  'Arabian The Evolution of  Italian Cinema.pdf',
#  '2015MathForComputerScience.pdf',
#  'Archive.zip',
#  'Complete the codes by fixing errors (5).pdf',
#  'Pandas.ipynb',
#  'Summ2RDrGiles.docx',
#  'Lecture 3 Business Cycle and Unemployment.docx',
#  'Giles_FD_Annotated_Bibliography__CS325.pdf',
#  'IPv4 Network Address Finding Exercises.docx',
#  'Giles_Annotated Bibliography; CS325.zip',
#  'Lab7.java',
#  'Homework 7.docx',
#  'Animal.java',
#  'Peer Review Worksheet [typed responses] (4).docx',
#  'Annotated_Bibliography__CS325.pdf',
#  'Lab 4.1 - Windows Registry_Updated-1.docx',
#  'Assignment 7.docx',
#  'EpicInstaller-14.6.2.dmg',
#  '11. Multipliers.ppt',
#  'Pronouns Exercise.pdf',
#  'project1-feedback.pdf',
#  'Creating and Combining Views — SwiftUI Tutorials ',
#  '~$ass Registration Form.docx',
#  'CMST101_SelfConcept.pptx',
#  '45855901_20231116101128.pdf',
#  'CalvinGilesid.pdf',
#  'ICEEE RequirementsSoftwareSpec (1).pdf',
#  'exit.asm',
#  'Lab6.java',
#  'ReviewerChecklistSumm2RD Codes.docx',
#  'Code.zip',
#  'Lab 1 - Do You Know Your Way-4.docx',
#  '260 - Days 22-23 - Section 3.3.pdf',
#  'Complete the codes by fixing errors (4).pdf',
#  'Philosophical Somebody Project.pptx',
#  'Cole Giles (1).docx',
#  'Lab Assignment #2.docx',
#  'invite.ics',
#  'Giles_Annotated Bibliography; CS325 (3)',
#  'R1_PracticeTest.pdf',
#  'Zoom-2.pkg',
#  'CollegeSuccess110SyllF2020.docx',
#  'Sec7-MatrixTransformations.pdf',
#  'Section2_0.1PPT_Spring20.pptx',
#  'Archive 2',
#  'Philosophy Somebody-1.pptx',
#  'Week 1 - Video Notes.pdf',
#  'assignment10.zip',
#  'login',
#  'essay 1 sample Tupac-3.docx',
#  'Assignment 6b.docx',
#  '~$urly-schedule-template-10.doc',
#  'mysql-workbench-community-8.0.42-macos-x86_64.dmg',
#  'Lecture 6 Monetary Policy.docx',
#  'Lecture 3 Business Cycle and Unemployment-2.docx',
#  'SQP1.doc',
#  'Assignment6a.mwb',
#  '~$gical Arguments.docx',
#  'ProjectGUIDraft.png',
#  'VSCode-darwin-universal.zip',
#  'Plautus.Phase-2 (Design).docx',
#  'Complete the codes by fixing errors (8).pdf',
#  'Giles_Annotated Bibliography; CS325 (1).zip',
#  'conceptPortfolioProblemSetThree.pptx',
#  'RStudio-2023.03.0-386.dmg',
#  'M330-Num2R-HWP01-Template.docx',
#  'github-logo.png',
#  '1611560231.629348.jpg',
#  '~$mework 2.docx',
#  'Lab5 (1).java',
#  'conceptPortfolioFinale (1).pptx',
#  'image.png',
#  'Lab 3',
#  'Peer Review Worksheet [typed responses] (2).docx',
#  'vanguard2025season.pdf',
#  'peer edit 1 essay 2.docx',
#  'arduino-ide_2.3.6_macOS_arm64.dmg',
#  'Lab 5  - Investigating MTF using FTK.docx',
#  'PHStranscript.pdf',
#  'DocumentationPlautus.docx',
#  'LOV.pdf',
#  'M1 238 Hybrid Spring 2024 Student.pptx',
#  'DocumentsPdf.pdf',
#  'Summ2RDrGiles Reviewed.docx']

# %%
import glob
csvfiles = glob.glob("*.csv")
csvfiles
# Out:
# ['damaged_students.csv',
#  'lysted-remit-8cd11e1c9e.csv',
#  'us_tourism.csv',
#  'verified_fans.csv',
#  'ba4bf594-025b-4348-a3c9-518c18d58451.csv',
#  'VF_SIGN_UP.csv',
#  'lysted-remit-3d79468388.csv',
#  'us_tourism2damage-1.csv',
#  'Calvin+Giles+country_with_index.csv',
#  'lysted-remit-10b3414e5e (1).csv',
#  '9e14d89e-d536-489d-ba4a-46c48301bd79.csv',
#  'lysted-remit-10b3414e5e.csv',
#  'Calvin+Giles+country_no_index.csv']

# %% [markdown]
# ## 1.1 Read CSV data

# %%
import pandas as pd
file_path = 'us_tourism.csv'

# Read the CSV file
dataframe_csv1 = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
dataframe_csv1.head(5)
# Out:
#       Region          State         Attraction  \
# 0  Northeast       New York  Statue of Liberty
# 1  Northeast  Massachusetts      Freedom Trail
# 2    Midwest       Illinois       Willis Tower
# 3    Midwest       Michigan    The Great Lakes
# 4      South        Florida       Disney World
#
#                               Description   Food Specialty  \
# 0                Iconic symbol of freedom           Bagels
# 1                 Historic 2.5-mile trail     Clam Chowder
# 2  One of the tallest buildings in the US  Deep-Dish Pizza
# 3       Largest group of freshwater lakes          Pasties
# 4            Famous theme park and resort     Key Lime Pie
#
#                             Food Description Best Time to Visit  \
# 0               Boiled and baked dough rings         Year-round
# 1        Creamy soup with clams and potatoes               Fall
# 2  Thick crust pizza with layers of toppings             Summer
# 3     Pastry filled with meat and vegetables             Winter
# 4         Sweet pie made with Key lime juice             Summer
#
#                    Notable Events
# 0      Fourth of July Celebration
# 1                 Boston Marathon
# 2                Taste of Chicago
# 3  Great Lakes Shipwreck Festival
# 4     Disney's Halloween Festival

# %% [markdown]
# ## 1.2 Handle damaged csv data

# %%
file_path2 = 'us_tourism2damage-1.csv'

# Read the CSV file

df = pd.read_csv(file_path2)

# Display the first few rows of the DataFrame
df
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-49-1cd1cdb6c564> in <module>
#       3 # Read the CSV file
#       4
# ----> 5 df = pd.read_csv(file_path2)
#       6
#       7 # Display the first few rows of the DataFrame
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     910     kwds.update(kwds_defaults)
#     911
# --> 912     return _read(filepath_or_buffer, kwds)
#     913
#     914
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     581
#     582     with parser:
# --> 583         return parser.read(nrows)
#     584
#     585
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1702                     columns,
#    1703                     col_dict,
# -> 1704                 ) = self._engine.read(  # type: ignore[attr-defined]
#    1705                     nrows
#    1706                 )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     232         try:
#     233             if self.low_memory:
# --> 234                 chunks = self._reader.read_low_memory(nrows)
#     235                 # destructive to chunks
#     236                 data = _concatenate_chunks(chunks)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 8 fields in line 48, saw 9

# %% [markdown]
# ### Cannot read damage file by pandas
#
# We need to read file line by line.

# %%
import csv

# Replace 'your_file.csv' with the path to your CSV file
file_path = 'us_tourism2damage-1.csv'

#read line by line, and filter the bad data
a =0
title = []
gooddata = []
baddata= []

# Please watch the tutorial and fill the code
# Your code:
with open (file_path, mode ='r',encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        if a == 0:
            title = row
        a+=1
        if len(row) == 5 and a!=0:
            gooddata.append(row)
        else:
            baddata.append(row)

# %%
gooddata
# Out:
# []

# %%
gooddf = pd.DataFrame(gooddata,columns = title)
gooddf
# Out:
# Empty DataFrame
# Columns: [Region, State, Attraction, Description, Food Specialty, Food Description, Best Time to Visit, Notable Events]
# Index: []

# %% [markdown]
# ## 2.1 Read json data

# %%
jsonfiles = glob.glob("*.json")
jsonfiles
# Out:
# ['damaged.json', 'true.json']

# %%
# Reading the JSON file
df = pd.read_json(jsonfiles[2],lines = True)

# Displaying the DataFrame
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-40-7111a87e343b> in <module>
#       1 # Reading the JSON file
# ----> 2 df = pd.read_json(jsonfiles[2],lines = True)
#       3
#       4 # Displaying the DataFrame
#       5 df.head(5)
#
# IndexError: list index out of range

# %% [markdown]
# ## 2.2 Handle damaged json Data

# %%
# Reading the JSON file
dfDamage = pd.read_json(jsonfiles[0],lines = True)

# Displaying the DataFrame
dfDamage.head(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-203b75893af9> in <module>
#       1 # Reading the JSON file
# ----> 2 dfDamage = pd.read_json(jsonfiles[0],lines = True)
#       3
#       4 # Displaying the DataFrame
#       5 dfDamage.head(5)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/json/_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     782         return json_reader
#     783     else:
# --> 784         return json_reader.read()
#     785
#     786
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/json/_json.py in read(self)
#     971                         data = ensure_str(self.data)
#     972                         data_lines = data.split("\n")
# --> 973                         obj = self._get_object_parser(self._combine_lines(data_lines))
#     974                 else:
#     975                     obj = self._get_object_parser(self.data)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/json/_json.py in _get_object_parser(self, json)
#     999         obj = None
#    1000         if typ == "frame":
# -> 1001             obj = FrameParser(json, **kwargs).parse()
#    1002
#    1003         if typ == "series" or obj is None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/json/_json.py in parse(self)
#    1132
#    1133     def parse(self):
# -> 1134         self._parse()
#    1135
#    1136         if self.obj is None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/json/_json.py in _parse(self)
#    1318         if orient == "columns":
#    1319             self.obj = DataFrame(
# -> 1320                 loads(json, precise_float=self.precise_float), dtype=None
#    1321             )
#    1322         elif orient == "split":
#
# ValueError: Expected object or value

# %% [markdown]
# ### 2.2.1 Simple demo

# %%
import json

# Example JSON data as a list of strings (each string is a JSON object)
json_data = [
    '{"name": "Alice", "age": 25, "city": "New York"}',
    '{"name": "Bob", "age": 30, "city": "San Francisco"}',
    '{"name": "Charlie", "age": 35}',
    '{"name": "Bib", "age": , "city": "Seattle"}',
    '{"name": "Bcob", "city": "Beijing"}',
    '{"name": "Bob", "xxxx": 30, "city": "San Francisco"}'
]

# %%
data = []
for json_str in json_data:
    try:
        # Attempt to parse each line as JSON
        json_obj = json.loads(json_str)

        # Handle missing or extra data
        if 'name' not in json_obj:
            json_obj['name'] = None
        if 'age' not in json_obj:
            json_obj['age'] = None
        if 'city' not in json_obj:
            json_obj['city'] = None

        # Append the valid JSON object to the list
        data.append(json_obj)
    
    except json.JSONDecodeError:
        print(f'Invalid Json data')

# data
# Convert the list of dictionaries to a pandas DataFrame (optional)
dfjson= pd.DataFrame(data)

#print
dfjson[['name','age','city']]
# Out:
# Invalid Json data
#       name   age           city
# 0    Alice  25.0       New York
# 1      Bob  30.0  San Francisco
# 2  Charlie  35.0           None
# 3     Bcob   NaN        Beijing
# 4      Bob   NaN  San Francisco

# %% [markdown]
# ### 2.2.3 Handle the damaged json file

# %%
file_path = 'damaged.json'  # Replace with your file path
data = []
title = ['Region', 'State', 'Attraction', 'Description', 
 'Food Specialty', 'Food Description', 'Best Time to Visit', 'Notable Events']

with open(file_path, 'r') as file:
    for line in file:
        try:
            # Parse the JSON string
            json_obj = json.loads(line)

            # Handle missing data by setting a default value
            # Your code

            # Append the processed JSON object to the list
            data.append(json_obj)
        except json.JSONDecodeError:
            print(f'Invalid Json data: {line}')
            

# Convert the list of dictionaries to a pandas DataFrame (optional)
df = pd.DataFrame(data)

# Display the DataFrame
df
# Out:
# Invalid Json data: {"Region":"Southwest","State":"Texas","Attraction":"The Alamo","Description":"Historic mission and fortress","Food Specialty":,"Food Description":"Fusion of Mexican and American cuisines","Best Time to Visit":"Spring","Notable Events":"San Antonio Fiesta"}
#
# Invalid Json data: {"Region":"South","State":"North Carolina","Attraction":"Great Smoky Mountains National Park","Description":,"Food Specialty":"Pulled Pork BBQ","Food Description":"Slow-cooked barbecue pork","Best Time to Visit":"Summer","Notable Events":"Mountain Music Festivals"}
#
# Invalid Json data: {"Region":"West","State":"Nevada","Attraction":"Las Vegas Strip",,"Food Specialty":"Buffet","Food Description":"All-you-can-eat buffets with various cuisines","Best Time to Visit":"Year-round","Notable Events":"Las Vegas New Year's Eve"}
#
# Invalid Json data: {"Region":"West","State":"Colorado","Attraction":"Rocky Mountain National Park",,"Food Specialty":"Rocky Mountain Oysters","Food Description":"Deep-fried bull testicles","Best Time to Visit":"Summer","Notable Events":"Frozen Dead Guy Days"}
#
# Invalid Json data: {"Region":"Northeast","State":"Connecticut","Attraction":,"Description":"The Museum of America and the Sea","Food Specialty":"Lobster Roll","Food Description":"Fresh lobster meat served on a roll","Best Time to Visit":"Summer","Notable Events":"Mystic Outdoor Art Festival"}
#                Region          State                            Attraction  \
# 0           Northeast       New York                     Statue of Liberty
# 1           Northeast  Massachusetts                         Freedom Trail
# 2             Midwest       Illinois                          Willis Tower
# 3             Midwest       Michigan                       The Great Lakes
# 4               South        Florida                          Disney World
# 5               South      Louisiana                        French Quarter
# 6                West     California                    Golden Gate Bridge
# 7                West         Hawaii        Hawaii Volcanoes National Park
# 8           Southwest        Arizona                          Grand Canyon
# 9   Pacific Northwest     Washington                          Space Needle
# 10  Pacific Northwest         Oregon                           Crater Lake
# 11          Northeast   Pennsylvania                          Liberty Bell
# 12          Northeast     New Jersey               Atlantic City Boardwalk
# 13            Midwest           Ohio                           Cedar Point
# 14            Midwest      Wisconsin                       Wisconsin Dells
# 15              South        Georgia            Savannah Historic District
# 16               West         Alaska                  Denali National Park
# 17          Southwest     New Mexico                      Carlsbad Caverns
# 18          Southwest       Oklahoma       Oklahoma City National Memorial
# 19          Northeast        Vermont                 Ben & Jerry's Factory
# 20          Northeast   Rhode Island                          The Breakers
# 21            Midwest        Indiana           Indianapolis Motor Speedway
# 22            Midwest       Missouri                          Gateway Arch
# 23              South       Kentucky            Mammoth Cave National Park
# 24              South      Tennessee                             Graceland
# 25               West           Utah                    Zion National Park
# 26          Southwest         Nevada                            Hoover Dam
# 27          Southwest     New Mexico             White Sands National Park
# 28  Pacific Northwest          Idaho                            Sun Valley
# 29  Pacific Northwest        Montana                 Glacier National Park
# 30          Northeast  New Hampshire                      Mount Washington
# 31            Midwest   North Dakota      Theodore Roosevelt National Park
# 32            Midwest   South Dakota                        Mount Rushmore
# 33              South        Alabama  USS Alabama Battleship Memorial Park
# 34              South    Mississippi      Vicksburg National Military Park
# 35               West         Oregon             Crater Lake National Park
# 36               West     Washington           Mount Rainier National Park
#
#                                           Description  \
# 0                            Iconic symbol of freedom
# 1                             Historic 2.5-mile trail
# 2              One of the tallest buildings in the US
# 3                   Largest group of freshwater lakes
# 4                        Famous theme park and resort
# 5                   Historic New Orleans neighborhood
# 6                            Iconic suspension bridge
# 7                            Home to active volcanoes
# 8                  One of the world's natural wonders
# 9           Futuristic tower with an observation deck
# 10                             Deepest lake in the US
# 11           Historic symbol of American independence
# 12           Famous boardwalk with casinos and hotels
# 13       Amusement park known for its roller coasters
# 14  Popular family vacation area known for its wat...
# 15  Well-preserved historic architecture and cobbl...
# 16               Home to North America's highest peak
# 17       Over 100 caves beneath the Chihuahuan Desert
# 18  Museum and memorial honoring the victims of th...
# 19                      Famous ice cream factory tour
# 20         Famous Newport mansion from the Gilded Age
# 21                         Iconic auto racing circuit
# 22  Iconic monument symbolizing the Westward Expan...
# 23                    The world's longest cave system
# 24             Elvis Presley's former home and museum
# 25                   Scenic canyons and hiking trails
# 26           Engineering marvel on the Colorado River
# 27                     Unique white gypsum sand dunes
# 28      Famous ski resort and outdoor recreation area
# 29    National park known for its glaciers and trails
# 30  The highest peak in the Northeastern United St...
# 31    Park known for its rugged landscape and history
# 32             Iconic sculpture of four US presidents
# 33                           Historic WWII battleship
# 34          Site of the Civil War Battle of Vicksburg
# 35    Famous for its deep blue lake and water clarity
# 36  Iconic volcano and the highest peak in Washington
#
#               Food Specialty  \
# 0                     Bagels
# 1               Clam Chowder
# 2            Deep-Dish Pizza
# 3                    Pasties
# 4               Key Lime Pie
# 5                  Jambalaya
# 6            Sourdough Bread
# 7                       Poke
# 8               Chimichangas
# 9                     Salmon
# 10           Marionberry Pie
# 11        Philly Cheesesteak
# 12          Salt Water Taffy
# 13                  Buckeyes
# 14              Cheese Curds
# 15             Peach Cobbler
# 16                 King Crab
# 17          Green Chile Stew
# 18       Chicken Fried Steak
# 19               Maple Syrup
# 20                Clam Cakes
# 21  Pork Tenderloin Sandwich
# 22       St. Louis-style BBQ
# 23                    Burgoo
# 24               Memphis BBQ
# 25          Funeral Potatoes
# 26           Shrimp Cocktail
# 27      Blue Corn Enchiladas
# 28            Idaho Potatoes
# 29             Huckleberries
# 30        Apple Cider Donuts
# 31             Knoephla Soup
# 32                   Chislic
# 33      Fried Green Tomatoes
# 34                   Catfish
# 35           Marionberry Pie
# 36                    Salmon
#
#                                      Food Description Best Time to Visit  \
# 0                        Boiled and baked dough rings         Year-round
# 1                 Creamy soup with clams and potatoes               Fall
# 2           Thick crust pizza with layers of toppings             Summer
# 3              Pastry filled with meat and vegetables             Winter
# 4                  Sweet pie made with Key lime juice             Summer
# 5                  Rice dish with meat and vegetables             Spring
# 6                 San Francisco's famous crusty bread             Summer
# 7                                      Raw fish salad         Year-round
# 8                                 Deep-fried burritos               Fall
# 9                               Fresh and smoked fish             Summer
# 10                  Pie made with local marionberries             Summer
# 11  Thinly sliced beef and melted cheese in a long...         Year-round
# 12                           Chewy, sweet taffy candy             Summer
# 13  Confections of peanut butter fudge dipped in c...               Fall
# 14                        Fried or fresh cheese curds             Summer
# 15      Sweet cobbler made with fresh Georgia peaches             Spring
# 16                             Alaskan king crab legs             Summer
# 17              Spicy stew with green chiles and pork               Fall
# 18                 Breaded and fried steak with gravy             Spring
# 19         Iconic syrup made from Vermont maple trees             Summer
# 20                  Deep-fried clam and dough mixture             Summer
# 21             Breaded and fried pork cutlet sandwich             Spring
# 22                 Grilled, then sauced barbeque ribs             Summer
# 23           Thick stew made with meat and vegetables               Fall
# 24                          Slow-cooked pork barbeque             Summer
# 25     Casserole made with potatoes, cheese, and soup             Spring
# 26                          Classic seafood appetizer         Year-round
# 27           Enchiladas made with blue corn tortillas             Spring
# 28             Famous potatoes, often baked or mashed             Winter
# 29                 Wild berries used in pies and jams             Summer
# 30                       Donuts made with apple cider               Fall
# 31                           Potato and dumpling soup               Fall
# 32     Cubed meat, typically lamb or beef, deep-fried             Summer
# 33                   Green tomatoes breaded and fried             Summer
# 34                 Cornmeal-breaded and fried catfish             Summer
# 35                  Pie made with local marionberries             Summer
# 36                              Fresh and smoked fish             Summer
#
#                                    Notable Events
# 0                      Fourth of July Celebration
# 1                                 Boston Marathon
# 2                                Taste of Chicago
# 3                  Great Lakes Shipwreck Festival
# 4                     Disney's Halloween Festival
# 5                                      Mardi Gras
# 6                     San Francisco Jazz Festival
# 7                                 Aloha Festivals
# 8                     Grand Canyon Music Festival
# 9             Seattle International Film Festival
# 10                    Oregon Shakespeare Festival
# 11                       Welcome America Festival
# 12                          Atlantic City Airshow
# 13                                Ohio State Fair
# 14                           Wisconsin State Fair
# 15                        Savannah Music Festival
# 16                   Iditarod Trail Sled Dog Race
# 17       Albuquerque International Balloon Fiesta
# 18                            Oklahoma State Fair
# 19                         Vermont Maple Festival
# 20                          Newport Jazz Festival
# 21                               Indianapolis 500
# 22                   St. Louis Bluesweek Festival
# 23                        Kentucky Derby Festival
# 24                                 Memphis in May
# 25                      Utah Shakespeare Festival
# 26              Las Vegas Electric Daisy Carnival
# 27       Albuquerque International Balloon Fiesta
# 28                 Trailing of the Sheep Festival
# 29                   Montana Huckleberry Festival
# 30                         Keene Pumpkin Festival
# 31             United Tribes International Powwow
# 32                       Sturgis Motorcycle Rally
# 33                       National Shrimp Festival
# 34  Mississippi Delta Blues and Heritage Festival
# 35                    Oregon Shakespeare Festival
# 36            Seattle International Film Festival

# %% [markdown]
# ## 3.1 Read Txt data
#
# Examples for **"split"**
# ```python
# text.split(" ")

# %%
h = 'Region: Northeast State: New York'
result_h = h.split(" ")
result_h
# Out:
# ['Region:', 'Northeast', 'State:', 'New', 'York']

# %%
file_path = 'unstructureddata.txt'  # use your file path

# Read and process the file
current_data= []
result= []
with open(file_path,'r') as file:
    for line in file:
        try:
            #Parse the JSON String
            json_obj = json.loads(line)

            #Handle missing data by setting a default value
            for key in title:
                if key not in json_obj:
                    json_obj[key] = None
            #Append the processed JSON object to the list
            data.append(json_obj)
        except json.JSONDecodeError:
            print(f'Invalid Json data: {line}')
# Out:
# Invalid Json data: Region: Northeast
#
# Invalid Json data: State: New York
#
# Invalid Json data: Attraction: Statue of Liberty
#
# Invalid Json data: Description: Iconic symbol of freedom
#
# Invalid Json data: Food Specialty: Bagels
#
# Invalid Json data: Food Description: Boiled and baked dough rings
#
# Invalid Json data: Best Time to Visit: Year-round
#
# Invalid Json data: Notable Events: Fourth of July Celebration
#
# Invalid Json data:
#
# Invalid Json data: Region: Northeast
#
# Invalid Json data: State: Massachusetts
#
# Invalid Json data: Attraction: Freedom Trail
#
# Invalid Json data: Description: Historic 2.5-mile trail
#
# Invalid Json data: Food Specialty: Clam Chowder
#
# Invalid Json data: Food Description: Creamy soup with clams and potatoes
#
# Invalid Json data: Best Time to Visit: Fall
#
# Invalid Json data: Notable Events: Boston Marathon
#
# Invalid Json data:
#
# Invalid Json data: Region: Midwest
#
# Invalid Json data: State: Illinois
#
# Invalid Json data: Attraction: Willis Tower
#
# Invalid Json data: Description: One of the tallest buildings in the US
#
# Invalid Json data: Food Specialty: Deep-Dish Pizza
#
# Invalid Json data: Food Description: Thick crust pizza with layers of toppings
#
# Invalid Json data: Best Time to Visit: Summer
#
# Invalid Json data: Notable Events: Taste of Chicago
#
# Invalid Json data:
#
# Invalid Json data: Region: Midwest
#
# Invalid Json data: State: Michigan
#
# Invalid Json data: Attraction: The Great Lakes
#
# Invalid Json data: Description: Largest group of freshwater lakes
#
# Invalid Json data: Food Specialty: Pasties
#
# Invalid Json data: Food Description: Pastry filled with meat and vegetables
#
# Invalid Json data: Best Time to Visit: Winter
#
# Invalid Json data: Notable Events: Great Lakes Shipwreck Festival
#
# Invalid Json data:
#
# Invalid Json data: Region: South
#
# Invalid Json data: State: Florida
#
# Invalid Json data: Attraction: Disney World
#
# Invalid Json data: Description: Famous theme park and resort
#
# Invalid Json data: Food Specialty: Key Lime Pie
#
# Invalid Json data: Food Description: Sweet pie made with Key lime juice
#
# Invalid Json data: Best Time to Visit: Summer
#
# Invalid Json data: Notable Events: Disney's Halloween Festival
#
# Invalid Json data:
#
# Invalid Json data: Region: South
#
# Invalid Json data: State: Louisiana
#
# Invalid Json data: Attraction: French Quarter
#
# Invalid Json data: Description: Historic New Orleans neighborhood
#
# Invalid Json data: Food Specialty: Jambalaya
#
# Invalid Json data: Food Description: Rice dish with meat and vegetables
#
# Invalid Json data: Best Time to Visit: Spring
#
# Invalid Json data: Notable Events: Mardi Gras
#
# Invalid Json data:
#
# Invalid Json data: Region: West
#
# Invalid Json data: State: California
#
# Invalid Json data: Attraction: Golden Gate Bridge
#
# Invalid Json data: Description: Iconic suspension bridge
#
# Invalid Json data: Food Specialty: Sourdough Bread
#
# Invalid Json data: Food Description: San Francisco's famous crusty bread
#
# Invalid Json data: Best Time to Visit: Summer
#
# Invalid Json data: Notable Events: San Francisco Jazz Festival
#
# Invalid Json data:
#
# Invalid Json data: Region: West
#
# Invalid Json data: State: Hawaii
#
# Invalid Json data: Attraction: Hawaii Volcanoes National Park
#
# Invalid Json data: Description: Home to active volcanoes
#
# Invalid Json data: Food Specialty: Poke
#
# Invalid Json data: Food Description: Raw fish salad
#
# Invalid Json data: Best Time to Visit: Year-round
#
# Invalid Json data: Notable Events: Aloha Festivals
#
# Invalid Json data:
#
# Invalid Json data: Region: Southwest
#
# Invalid Json data: State: Texas
#
# Invalid Json data: Attraction: The Alamo
#
# Invalid Json data: Description: Historic mission and fortress
#
# Invalid Json data: Food Specialty: Tex-Mex Cuisine
#
# Invalid Json data: Food Description: Fusion of Mexican and American cuisines
#
# Invalid Json data: Best Time to Visit: Spring
#
# Invalid Json data: Notable Events: San Antonio Fiesta
#
# Invalid Json data:
#
# Invalid Json data: Region: Southwest
#
# Invalid Json data: State: Arizona
#
# Invalid Json data: Attraction: Grand Canyon
#
# Invalid Json data: Description: One of the world's natural wonders
#
# Invalid Json data: Food Specialty: Chimichangas
#
# Invalid Json data: Food Description: Deep-fried burritos
#
# Invalid Json data: Best Time to Visit: Fall
#
# Invalid Json data: Notable Events: Grand Canyon Music Festival
#
# Invalid Json data:
#
# Invalid Json data: Region: Pacific Northwest
#
# Invalid Json data: State: Washington
#
# Invalid Json data: Attraction: Space Needle
#
# Invalid Json data: Description: Futuristic tower with an observation deck
#
# Invalid Json data: Food Specialty: Salmon
#
# Invalid Json data: Food Description: Fresh and smoked fish
#
# Invalid Json data: Best Time to Visit: Summer
#
# Invalid Json data: Notable Events: Seattle International Film Festival
#
# Invalid Json data:
#
# Invalid Json data: Region: Pacific Northwest
#
# Invalid Json data: State: Oregon
#
# Invalid Json data: Attraction: Crater Lake
#
# Invalid Json data: Description: Deepest lake in the US
#
# Invalid Json data: Food Specialty: Marionberry Pie
#
# Invalid Json data: Food Description: Pie made with local marionberries
#
# Invalid Json data: Best Time to Visit: Summer
#
# Invalid Json data: Notable Events: Oregon Shakespeare Festival
#
# Invalid Json data:
#
# Invalid Json data: Region: Northeast
#
# Invalid Json data: State: Pennsylvania
#
# Invalid Json data: Attraction: Liberty Bell
#
# Invalid Json data: Description: Historic symbol of American independence
#
# Invalid Json data: Food Specialty: Philly Cheesesteak
#
# Invalid Json data: Food Description: Thinly sliced beef and melted cheese in a long roll
#
# Invalid Json data: Best Time to Visit: Year-round
#
# Invalid Json data: Notable Events: Welcome America Festival
#
# Invalid Json data:
#
# Invalid Json data: Region: Northeast
#
# Invalid Json data: State: New Jersey
#
# Invalid Json data: Attraction: Atlantic City Boardwalk
#
# Invalid Json data: Description: Famous boardwalk with casinos and hotels
#
# Invalid Json data: Food Specialty: Salt Water Taffy
#
# Invalid Json data: Food Description: Chewy, sweet taffy candy
#
# Invalid Json data: Best Time to Visit: Summer
#
# Invalid Json data: Notable Events: Atlantic City Airshow
#
# Invalid Json data:
#
# Invalid Json data: Region: Midwest
#
# Invalid Json data: State: Ohio
#
# Invalid Json data: Attraction: Cedar Point
#
# Invalid Json data: Description: Amusement park known for its roller coasters
#
# Invalid Json data: Food Specialty: Buckeyes
#
# Invalid Json data: Food Description: Confections of peanut butter fudge dipped in chocolate
#
# Invalid Json data: Best Time to Visit: Fall
#
# Invalid Json data: Notable Events: Ohio State Fair
#
# Invalid Json data:
#
# Invalid Json data: Region: Midwest
#
# Invalid Json data: State: Wisconsin
#
# Invalid Json data: Attraction: Wisconsin Dells
#
# Invalid Json data: Description: Popular family vacation area known for its water parks
#
# Invalid Json data: Food Specialty: Cheese Curds
#
# Invalid Json data: Food Description: Fried or fresh cheese curds
#
# Invalid Json data: Best Time to Visit: Summer
#
# Invalid Json data: Notable Events: Wisconsin State Fair
#
# Invalid Json data:
#
# Invalid Json data: Region: South
#
# Invalid Json data: State: North Carolina
#
# Invalid Json data: Attraction: Great Smoky Mountains National Park
#
# Invalid Json data: Description: Popular national park with diverse plant and animal life
#
# Invalid Json data: Food Specialty: Pulled Pork BBQ
#
# Invalid Json data: Food Description: Slow-cooked barbecue pork
#
# Invalid Json data: Best Time to Visit: Summer
#
# Invalid Json data: Notable Events: Mountain Music Festivals
#
# Invalid Json data:
#
# Invalid Json data: Region: South
#
# Invalid Json data: State: Georgia
#
# Invalid Json data: Attraction: Savannah Historic District
#
# Invalid Json data: Description: Well-preserved historic architecture and cobblestone streets
#
# Invalid Json data: Food Specialty: Peach Cobbler
#
# Invalid Json data: Food Description: Sweet cobbler made with fresh Georgia peaches
#
# Invalid Json data: Best Time to Visit: Spring
#
# Invalid Json data: Notable Events: Savannah Music Festival
#
# Invalid Json data:
#
# Invalid Json data: Region: West
#
# Invalid Json data: State: Alaska
#
# Invalid Json data: Attraction: Denali National Park
#
# Invalid Json data: Description: Home to North America's highest peak
#
# Invalid Json data: Food Specialty: King Crab
#
# Invalid Json data: Food Description: Alaskan king crab legs
#
# Invalid Json data: Best Time to Visit: Summer
#
# Invalid Json data: Notable Events: Iditarod Trail Sled Dog Race
#
# Invalid Json data:
#
# Invalid Json data: Region: West
#
# Invalid Json data: State: Nevada
#
# Invalid Json data: Attraction: Las Vegas Strip
#
# Invalid Json data: Description: Famous for its vibrant nightlife and casinos
#
# Invalid Json data: Food Specialty: Buffet
#
# Invalid Json data: Food Description: All-you-can-eat buffets with various cuisines
#
# Invalid Json data: Best Time to Visit: Year-round
#
# Invalid Json data: Notable Events: Las Vegas New Year's Eve
#
# Invalid Json data:
#
# Invalid Json data: Region: Southwest
#
# Invalid Json data: State: New Mexico
#
# Invalid Json data: Attraction: Carlsbad Caverns
#
# Invalid Json data: Description: Over 100 caves beneath the Chihuahuan Desert
#
# Invalid Json data: Food Specialty: Green Chile Stew
#
# Invalid Json data: Food Description: Spicy stew with green chiles and pork
#
# Invalid Json data: Best Time to Visit: Fall
#
# Invalid Json data: Notable Events: Albuquerque International Balloon Fiesta
#
# Invalid Json data:
#
# Invalid Json data: Region: Southwest
#
# Invalid Json data: State: Oklahoma
#
# Invalid Json data: Attraction: Oklahoma City National Memorial
#
# Invalid Json data: Description: Museum and memorial honoring the victims of the 1995 bombing
#
# Invalid Json data: Food Specialty: Chicken Fried Steak
#
# Invalid Json data: Food Description: Breaded and fried steak with gravy
#
# Invalid Json data: Best Time to Visit: Spring
#
# Invalid Json data: Notable Events: Oklahoma State Fair
#
# Invalid Json data:
#
# Invalid Json data: Region: Northeast
#
# Invalid Json data: State: Vermont
#
# Invalid Json data: Attraction: Ben & Jerry's Factory
#
# Invalid Json data: Description: Famous ice cream factory tour
#
# Invalid Json data: Food Specialty: Maple Syrup
#
# Invalid Json data: Food Description: Iconic syrup made from Vermont maple trees
#
# Invalid Json data: Best Time to Visit: Summer
#
# Invalid Json data: Notable Events: Vermont Maple Festival
#
# Invalid Json data:
#
# Invalid Json data: Region: Northeast
#
# Invalid Json data: State: Rhode Island
#
# Invalid Json data: Attraction: The Breakers
#
# Invalid Json data: Description: Famous Newport mansion from the Gilded Age
#
# Invalid Json data: Food Specialty: Clam Cakes
#
# Invalid Json data: Food Description: Deep-fried clam and dough mixture
#
# Invalid Json data: Best Time to Visit: Summer
#
# Invalid Json data: Notable Events: Newport Jazz Festival
#
# Invalid Json data:
#
# Invalid Json data: Region: Midwest
#
# Invalid Json data: State: Indiana
#
# Invalid Json data: Attraction: Indianapolis Motor Speedway
#
# Invalid Json data: Description: Iconic auto racing circuit
#
# Invalid Json data: Food Specialty: Pork Tenderloin Sandwich
#
# Invalid Json data: Food Description: Breaded and fried pork cutlet sandwich
#
# Invalid Json data: Best Time to Visit: Spring
#
# Invalid Json data: Notable Events: Indianapolis 500
#
# Invalid Json data:
#
# Invalid Json data: Region: Midwest
#
# Invalid Json data: State: Missouri
#
# Invalid Json data: Attraction: Gateway Arch
#
# Invalid Json data: Description: Iconic monument symbolizing the Westward Expansion
#
# Invalid Json data: Food Specialty: St. Louis-style BBQ
#
# Invalid Json data: Food Description: Grilled, then sauced barbeque ribs
#
# Invalid Json data: Best Time to Visit: Summer
#
# Invalid Json data: Notable Events: St. Louis Bluesweek Festival
#
# Invalid Json data:
#
# Invalid Json data: Region: South
#
# Invalid Json data: State: Kentucky
#
# Invalid Json data: Attraction: Mammoth Cave National Park
#
# Invalid Json data: Description: The world's longest cave system
#
# Invalid Json data: Food Specialty: Burgoo
#
# Invalid Json data: Food Description: Thick stew made with meat and vegetables
#
# Invalid Json data: Best Time to Visit: Fall
#
# Invalid Json data: Notable Events: Kentucky Derby Festival
#
# Invalid Json data:
#
# Invalid Json data: Region: South
#
# Invalid Json data: State: Tennessee
#
# Invalid Json data: Attraction: Graceland
#
# Invalid Json data: Description: Elvis Presley's former home and museum
#
# Invalid Json data: Food Specialty: Memphis BBQ
#
# Invalid Json data: Food Description: Slow-cooked pork barbeque
#
# Invalid Json data: Best Time to Visit: Summer
#
# Invalid Json data: Notable Events: Memphis in May
#
# Invalid Json data:
#
# Invalid Json data: Region: West
#
# Invalid Json data: State: Colorado
#
# Invalid Json data: Attraction: Rocky Mountain National Park
#
# Invalid Json data: Description: National park known for its mountainous landscapes
#
# Invalid Json data: Food Specialty: Rocky Mountain Oysters
#
# Invalid Json data: Food Description: Deep-fried bull testicles
#
# Invalid Json data: Best Time to Visit: Summer
#
# Invalid Json data: Notable Events: Frozen Dead Guy Days
#
# Invalid Json data:
#
# Invalid Json data: Region: West
#
# Invalid Json data: State: Utah
#
# Invalid Json data: Attraction: Zion National Park
#
# Invalid Json data: Description: Scenic canyons and hiking trails
#
# Invalid Json data: Food Specialty: Funeral Potatoes
#
# Invalid Json data: Food Description: Casserole made with potatoes, cheese, and soup
#
# Invalid Json data: Best Time to Visit: Spring
#
# Invalid Json data: Notable Events: Utah Shakespeare Festival
#
# Invalid Json data:
#
# Invalid Json data: Region: Southwest
#
# Invalid Json data: State: Nevada
#
# Invalid Json data: Attraction: Hoover Dam
#
# Invalid Json data: Description: Engineering marvel on the Colorado River
#
# Invalid Json data: Food Specialty: Shrimp Cocktail
#
# Invalid Json data: Food Description: Classic seafood appetizer
#
# Invalid Json data: Best Time to Visit: Year-round
#
# Invalid Json data: Notable Events: Las Vegas Electric Daisy Carnival
#
# Invalid Json data:
#
# Invalid Json data: Region: Southwest
#
# Invalid Json data: State: New Mexico
#
# Invalid Json data: Attraction: White Sands National Park
#
# Invalid Json data: Description: Unique white gypsum sand dunes
#
# Invalid Json data: Food Specialty: Blue Corn Enchiladas
#
# Invalid Json data: Food Description: Enchiladas made with blue corn tortillas
#
# Invalid Json data: Best Time to Visit: Spring
#
# Invalid Json data: Notable Events: Albuquerque International Balloon Fiesta
#
# Invalid Json data:
#
# Invalid Json data: Region: Pacific Northwest
#
# Invalid Json data: State: Idaho
#
# Invalid Json data: Attraction: Sun Valley
#
# Invalid Json data: Description: Famous ski resort and outdoor recreation area
#
# Invalid Json data: Food Specialty: Idaho Potatoes
#
# Invalid Json data: Food Description: Famous potatoes, often baked or mashed
#
# Invalid Json data: Best Time to Visit: Winter
#
# Invalid Json data: Notable Events: Trailing of the Sheep Festival
#
# Invalid Json data:
#
# Invalid Json data: Region: Pacific Northwest
#
# Invalid Json data: State: Montana
#
# Invalid Json data: Attraction: Glacier National Park
#
# Invalid Json data: Description: National park known for its glaciers and trails
#
# Invalid Json data: Food Specialty: Huckleberries
#
# Invalid Json data: Food Description: Wild berries used in pies and jams
#
# Invalid Json data: Best Time to Visit: Summer
#
# Invalid Json data: Notable Events: Montana Huckleberry Festival
#
# Invalid Json data:
#
# Invalid Json data: Region: Northeast
#
# Invalid Json data: State: Connecticut
#
# Invalid Json data: Attraction: Mystic Seaport
#
# Invalid Json data: Description: The Museum of America and the Sea
#
# Invalid Json data: Food Specialty: Lobster Roll
#
# Invalid Json data: Food Description: Fresh lobster meat served on a roll
#
# Invalid Json data: Best Time to Visit: Summer
#
# Invalid Json data: Notable Events: Mystic Outdoor Art Festival
#
# Invalid Json data:
#
# Invalid Json data: Region: Northeast
#
# Invalid Json data: State: New Hampshire
#
# Invalid Json data: Attraction: Mount Washington
#
# Invalid Json data: Description: The highest peak in the Northeastern United States
#
# Invalid Json data: Food Specialty: Apple Cider Donuts
#
# Invalid Json data: Food Description: Donuts made with apple cider
#
# Invalid Json data: Best Time to Visit: Fall
#
# Invalid Json data: Notable Events: Keene Pumpkin Festival
#
# Invalid Json data:
#
# Invalid Json data: Region: Midwest
#
# Invalid Json data: State: North Dakota
#
# Invalid Json data: Attraction: Theodore Roosevelt National Park
#
# Invalid Json data: Description: Park known for its rugged landscape and history
#
# Invalid Json data: Food Specialty: Knoephla Soup
#
# Invalid Json data: Food Description: Potato and dumpling soup
#
# Invalid Json data: Best Time to Visit: Fall
#
# Invalid Json data: Notable Events: United Tribes International Powwow
#
# Invalid Json data:
#
# Invalid Json data: Region: Midwest
#
# Invalid Json data: State: South Dakota
#
# Invalid Json data: Attraction: Mount Rushmore
#
# Invalid Json data: Description: Iconic sculpture of four US presidents
#
# Invalid Json data: Food Specialty: Chislic
#
# Invalid Json data: Food Description: Cubed meat, typically lamb or beef, deep-fried
#
# Invalid Json data: Best Time to Visit: Summer
#
# Invalid Json data: Notable Events: Sturgis Motorcycle Rally
#
# Invalid Json data:
#
# Invalid Json data: Region: South
#
# Invalid Json data: State: Alabama
#
# Invalid Json data: Attraction: USS Alabama Battleship Memorial Park
#
# Invalid Json data: Description: Historic WWII battleship
#
# Invalid Json data: Food Specialty: Fried Green Tomatoes
#
# Invalid Json data: Food Description: Green tomatoes breaded and fried
#
# Invalid Json data: Best Time to Visit: Summer
#
# Invalid Json data: Notable Events: National Shrimp Festival
#
# Invalid Json data:
#
# Invalid Json data: Region: South
#
# Invalid Json data: State: Mississippi
#
# Invalid Json data: Attraction: Vicksburg National Military Park
#
# Invalid Json data: Description: Site of the Civil War Battle of Vicksburg
#
# Invalid Json data: Food Specialty: Catfish
#
# Invalid Json data: Food Description: Cornmeal-breaded and fried catfish
#
# Invalid Json data: Best Time to Visit: Summer
#
# Invalid Json data: Notable Events: Mississippi Delta Blues and Heritage Festival
#
# Invalid Json data:
#
# Invalid Json data: Region: West
#
# Invalid Json data: State: Oregon
#
# Invalid Json data: Attraction: Crater Lake National Park
#
# Invalid Json data: Description: Famous for its deep blue lake and water clarity
#
# Invalid Json data: Food Specialty: Marionberry Pie
#
# Invalid Json data: Food Description: Pie made with local marionberries
#
# Invalid Json data: Best Time to Visit: Summer
#
# Invalid Json data: Notable Events: Oregon Shakespeare Festival
#
# Invalid Json data:
#
# Invalid Json data: Region: West
#
# Invalid Json data: State: Washington
#
# Invalid Json data: Attraction: Mount Rainier National Park
#
# Invalid Json data: Description: Iconic volcano and the highest peak in Washington
#
# Invalid Json data: Food Specialty: Salmon
#
# Invalid Json data: Food Description: Fresh and smoked fish
#
# Invalid Json data: Best Time to Visit: Summer
#
# Invalid Json data: Notable Events: Seattle International Film Festival
#
# Invalid Json data:

# %%
# # Convert the list of dictionaries into a DataFrame
df = pd.DataFrame(result)
# # Display the DataFrame
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## 3.2 Handle damaged txt data

# %%
import pandas as pd

# %%
"""Your turn -- Class practice"""
file_path = 'damaged_data.txt'  # use your file path

# Define the expected keys
expected_keys = ["Region", "State", "Attraction", "Description", 
                 "Food Specialty", "Food Description", 
                 "Best Time to Visit", "Notable Events"]


# Function to process a block of text and return a dictionary
def process_block_with_damage(block):
    entity = {key: None for key in expected_keys}
    #Your code:
    for item in block:
        if ": " in item:
            key,value = item.split(": ")
            if key in entity:
                entity[key] = value
                
    return entity

# Read and process the file
current_data= []
result= []
with open(file_path,'r') as file:
    for line in file:
        if line.strip() =="":
            processeddata = process_block_with_damage(current_data)
            result.append(processeddata)
            current_data = []
        else:
            current_data.append(line.strip())
        
# Convert the list of dictionaries into a DataFrame
dfnew = pd.DataFrame(result)

# Display the DataFrame
dfnew
# Out:
#                Region           State                            Attraction  \
# 0           Northeast        New York                     Statue of Liberty
# 1           Northeast   Massachusetts                         Freedom Trail
# 2             Midwest        Illinois                          Willis Tower
# 3             Midwest        Michigan                       The Great Lakes
# 4               South         Florida                          Disney World
# 5               South       Louisiana                        French Quarter
# 6                West      California                    Golden Gate Bridge
# 7                West          Hawaii        Hawaii Volcanoes National Park
# 8           Southwest           Texas                             The Alamo
# 9           Southwest         Arizona                          Grand Canyon
# 10  Pacific Northwest      Washington                          Space Needle
# 11  Pacific Northwest          Oregon                           Crater Lake
# 12          Northeast    Pennsylvania                          Liberty Bell
# 13          Northeast      New Jersey               Atlantic City Boardwalk
# 14            Midwest            Ohio                           Cedar Point
# 15            Midwest       Wisconsin                       Wisconsin Dells
# 16              South  North Carolina   Great Smoky Mountains National Park
# 17              South         Georgia            Savannah Historic District
# 18               West          Alaska                  Denali National Park
# 19               West          Nevada                       Las Vegas Strip
# 20          Southwest      New Mexico                      Carlsbad Caverns
# 21          Southwest        Oklahoma       Oklahoma City National Memorial
# 22          Northeast         Vermont                 Ben & Jerry's Factory
# 23          Northeast    Rhode Island                          The Breakers
# 24            Midwest         Indiana           Indianapolis Motor Speedway
# 25            Midwest        Missouri                          Gateway Arch
# 26              South        Kentucky            Mammoth Cave National Park
# 27              South       Tennessee                             Graceland
# 28               West        Colorado          Rocky Mountain National Park
# 29               West            Utah                    Zion National Park
# 30          Southwest          Nevada                            Hoover Dam
# 31          Southwest      New Mexico             White Sands National Park
# 32  Pacific Northwest           Idaho                            Sun Valley
# 33  Pacific Northwest         Montana                 Glacier National Park
# 34          Northeast     Connecticut                        Mystic Seaport
# 35          Northeast   New Hampshire                      Mount Washington
# 36            Midwest    North Dakota      Theodore Roosevelt National Park
# 37            Midwest    South Dakota                        Mount Rushmore
# 38              South         Alabama  USS Alabama Battleship Memorial Park
# 39              South     Mississippi      Vicksburg National Military Park
# 40               West          Oregon             Crater Lake National Park
# 41               West      Washington           Mount Rainier National Park
#
#                                           Description  \
# 0                            Iconic symbol of freedom
# 1                             Historic 2.5-mile trail
# 2              One of the tallest buildings in the US
# 3                   Largest group of freshwater lakes
# 4                        Famous theme park and resort
# 5                   Historic New Orleans neighborhood
# 6                            Iconic suspension bridge
# 7                            Home to active volcanoes
# 8                       Historic mission and fortress
# 9                  One of the world's natural wonders
# 10          Futuristic tower with an observation deck
# 11                             Deepest lake in the US
# 12           Historic symbol of American independence
# 13           Famous boardwalk with casinos and hotels
# 14       Amusement park known for its roller coasters
# 15  Popular family vacation area known for its wat...
# 16  Popular national park with diverse plant and a...
# 17  Well-preserved historic architecture and cobbl...
# 18               Home to North America's highest peak
# 19       Famous for its vibrant nightlife and casinos
# 20       Over 100 caves beneath the Chihuahuan Desert
# 21  Museum and memorial honoring the victims of th...
# 22                      Famous ice cream factory tour
# 23         Famous Newport mansion from the Gilded Age
# 24                         Iconic auto racing circuit
# 25  Iconic monument symbolizing the Westward Expan...
# 26                    The world's longest cave system
# 27             Elvis Presley's former home and museum
# 28  National park known for its mountainous landsc...
# 29                   Scenic canyons and hiking trails
# 30           Engineering marvel on the Colorado River
# 31                     Unique white gypsum sand dunes
# 32      Famous ski resort and outdoor recreation area
# 33    National park known for its glaciers and trails
# 34                  The Museum of America and the Sea
# 35  The highest peak in the Northeastern United St...
# 36    Park known for its rugged landscape and history
# 37             Iconic sculpture of four US presidents
# 38                           Historic WWII battleship
# 39          Site of the Civil War Battle of Vicksburg
# 40    Famous for its deep blue lake and water clarity
# 41  Iconic volcano and the highest peak in Washington
#
#               Food Specialty  \
# 0                     Bagels
# 1                       None
# 2                       None
# 3                    Pasties
# 4                       None
# 5                  Jambalaya
# 6            Sourdough Bread
# 7                       Poke
# 8            Tex-Mex Cuisine
# 9               Chimichangas
# 10                    Salmon
# 11           Marionberry Pie
# 12        Philly Cheesesteak
# 13          Salt Water Taffy
# 14                  Buckeyes
# 15              Cheese Curds
# 16           Pulled Pork BBQ
# 17             Peach Cobbler
# 18                 King Crab
# 19                    Buffet
# 20          Green Chile Stew
# 21       Chicken Fried Steak
# 22               Maple Syrup
# 23                Clam Cakes
# 24  Pork Tenderloin Sandwich
# 25       St. Louis-style BBQ
# 26                    Burgoo
# 27               Memphis BBQ
# 28    Rocky Mountain Oysters
# 29          Funeral Potatoes
# 30           Shrimp Cocktail
# 31      Blue Corn Enchiladas
# 32            Idaho Potatoes
# 33             Huckleberries
# 34              Lobster Roll
# 35        Apple Cider Donuts
# 36             Knoephla Soup
# 37                   Chislic
# 38      Fried Green Tomatoes
# 39                   Catfish
# 40           Marionberry Pie
# 41                    Salmon
#
#                                      Food Description Best Time to Visit  \
# 0                        Boiled and baked dough rings         Year-round
# 1                 Creamy soup with clams and potatoes               Fall
# 2           Thick crust pizza with layers of toppings             Summer
# 3              Pastry filled with meat and vegetables             Winter
# 4                  Sweet pie made with Key lime juice             Summer
# 5                  Rice dish with meat and vegetables             Spring
# 6                 San Francisco's famous crusty bread             Summer
# 7                                      Raw fish salad         Year-round
# 8             Fusion of Mexican and American cuisines             Spring
# 9                                 Deep-fried burritos               Fall
# 10                                               None             Summer
# 11                  Pie made with local marionberries             Summer
# 12  Thinly sliced beef and melted cheese in a long...         Year-round
# 13                           Chewy, sweet taffy candy             Summer
# 14  Confections of peanut butter fudge dipped in c...               Fall
# 15                        Fried or fresh cheese curds             Summer
# 16                          Slow-cooked barbecue pork             Summer
# 17      Sweet cobbler made with fresh Georgia peaches             Spring
# 18                             Alaskan king crab legs             Summer
# 19      All-you-can-eat buffets with various cuisines         Year-round
# 20              Spicy stew with green chiles and pork               Fall
# 21                 Breaded and fried steak with gravy             Spring
# 22         Iconic syrup made from Vermont maple trees             Summer
# 23                  Deep-fried clam and dough mixture             Summer
# 24             Breaded and fried pork cutlet sandwich             Spring
# 25                 Grilled, then sauced barbeque ribs             Summer
# 26           Thick stew made with meat and vegetables               Fall
# 27                          Slow-cooked pork barbeque             Summer
# 28                          Deep-fried bull testicles             Summer
# 29     Casserole made with potatoes, cheese, and soup             Spring
# 30                          Classic seafood appetizer         Year-round
# 31           Enchiladas made with blue corn tortillas             Spring
# 32             Famous potatoes, often baked or mashed             Winter
# 33                 Wild berries used in pies and jams             Summer
# 34                Fresh lobster meat served on a roll             Summer
# 35                       Donuts made with apple cider               Fall
# 36                           Potato and dumpling soup               Fall
# 37     Cubed meat, typically lamb or beef, deep-fried             Summer
# 38                   Green tomatoes breaded and fried             Summer
# 39                 Cornmeal-breaded and fried catfish             Summer
# 40                  Pie made with local marionberries             Summer
# 41                              Fresh and smoked fish             Summer
#
#                                    Notable Events
# 0                      Fourth of July Celebration
# 1                                 Boston Marathon
# 2                                Taste of Chicago
# 3                  Great Lakes Shipwreck Festival
# 4                     Disney's Halloween Festival
# 5                                      Mardi Gras
# 6                     San Francisco Jazz Festival
# 7                                 Aloha Festivals
# 8                              San Antonio Fiesta
# 9                     Grand Canyon Music Festival
# 10            Seattle International Film Festival
# 11                    Oregon Shakespeare Festival
# 12                       Welcome America Festival
# 13                          Atlantic City Airshow
# 14                                Ohio State Fair
# 15                           Wisconsin State Fair
# 16                       Mountain Music Festivals
# 17                        Savannah Music Festival
# 18                   Iditarod Trail Sled Dog Race
# 19                       Las Vegas New Year's Eve
# 20       Albuquerque International Balloon Fiesta
# 21                            Oklahoma State Fair
# 22                         Vermont Maple Festival
# 23                          Newport Jazz Festival
# 24                               Indianapolis 500
# 25                   St. Louis Bluesweek Festival
# 26                        Kentucky Derby Festival
# 27                                 Memphis in May
# 28                           Frozen Dead Guy Days
# 29                      Utah Shakespeare Festival
# 30              Las Vegas Electric Daisy Carnival
# 31       Albuquerque International Balloon Fiesta
# 32                 Trailing of the Sheep Festival
# 33                   Montana Huckleberry Festival
# 34                    Mystic Outdoor Art Festival
# 35                         Keene Pumpkin Festival
# 36             United Tribes International Powwow
# 37                       Sturgis Motorcycle Rally
# 38                       National Shrimp Festival
# 39  Mississippi Delta Blues and Heritage Festival
# 40                    Oregon Shakespeare Festival
# 41            Seattle International Film Festival

# %% [markdown]
# ### Practice 🧪 Lab: Cleaning “Damaged” Data with pandas
#
# In this practice, you’ll practice detecting and fixing common data problems:
#
# - Rows with **missing fields**
# - Rows with **extra fields** (e.g., too many columns due to extra commas)
# - **Wrong types** (strings in numeric columns)
# - **Out-of-range values** (e.g., impossible GPA)
# - Empty strings vs true missing values (`NaN`)
#
# You will:
# 1) Load a deliberately “damaged” CSV,
# 2) Identify & filter bad rows,
# 3) Coerce types, and
# 4) Produce a clean DataFrame ready for analysis.

# %%
# 🚧 Create a deliberately “damaged” CSV (run this cell once)
source_csv = """Student_ID,Name,Major,Credits,GPA,Grad_Year
1001,Alice,Computer Science,120,3.85,2026
1002,Bob,Math, ,3.10,2025
1003,Charlie,Physics,98,3O,2024
1004,Diana,Economics,140,4.7,2023
1005,Ed,Computer Science,129,N/A,2027
1006, ,Biology,88,2.95,2028
1007,Grace,Physics,101,3.40,2029,EXTRA_TOKEN
,Henry,Math,64,2.70,2026
1009,Ivy,,110,3.20,2025
1010,Jack,Economics,215,3.50,2035
1011,Kate,Chemistry,95,3.00,
1012,Liam,Computer Science,NaN,3.60,2024
1013,Mia,Math,77,,2025
1014,Noah,Physics,85,3.25,2027
1015,Olivia,Economics,,2.80,2026
"""

# %%
with open('damaged_students.csv', 'w') as file:
    file.write(source_csv)

# %%
file_name = 'damaged_students.csv'
a=0
tile=[]
gooddata=[]
baddata=[]

#open file
with open (file_name, mode ='r',encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        if a == 0:
            title = row
        a+=1
        if len(row) == 6 and a!=0:
            gooddata.append(row)
        else:
            baddata.append(row)

# %%
gooddata
# Out:
# [['Student_ID', 'Name', 'Major', 'Credits', 'GPA', 'Grad_Year'],
#  ['1001', 'Alice', 'Computer Science', '120', '3.85', '2026'],
#  ['1002', 'Bob', 'Math', ' ', '3.10', '2025'],
#  ['1003', 'Charlie', 'Physics', '98', '3O', '2024'],
#  ['1004', 'Diana', 'Economics', '140', '4.7', '2023'],
#  ['1005', 'Ed', 'Computer Science', '129', 'N/A', '2027'],
#  ['1006', ' ', 'Biology', '88', '2.95', '2028'],
#  ['', 'Henry', 'Math', '64', '2.70', '2026'],
#  ['1009', 'Ivy', '', '110', '3.20', '2025'],
#  ['1010', 'Jack', 'Economics', '215', '3.50', '2035'],
#  ['1011', 'Kate', 'Chemistry', '95', '3.00', ''],
#  ['1012', 'Liam', 'Computer Science', 'NaN', '3.60', '2024'],
#  ['1013', 'Mia', 'Math', '77', '', '2025'],
#  ['1014', 'Noah', 'Physics', '85', '3.25', '2027'],
#  ['1015', 'Olivia', 'Economics', '', '2.80', '2026']]

# %%
baddata
# Out:
# [['Student_ID', 'Name', 'Major', 'Credits', 'GPA', 'Grad_Year'],
#  ['1001', 'Alice', 'Computer Science', '120', '3.85', '2026'],
#  ['1002', 'Bob', 'Math', ' ', '3.10', '2025'],
#  ['1003', 'Charlie', 'Physics', '98', '3O', '2024'],
#  ['1004', 'Diana', 'Economics', '140', '4.7', '2023'],
#  ['1005', 'Ed', 'Computer Science', '129', 'N/A', '2027'],
#  ['1006', ' ', 'Biology', '88', '2.95', '2028'],
#  ['1007', 'Grace', 'Physics', '101', '3.40', '2029', 'EXTRA_TOKEN'],
#  ['', 'Henry', 'Math', '64', '2.70', '2026'],
#  ['1009', 'Ivy', '', '110', '3.20', '2025'],
#  ['1010', 'Jack', 'Economics', '215', '3.50', '2035'],
#  ['1011', 'Kate', 'Chemistry', '95', '3.00', ''],
#  ['1012', 'Liam', 'Computer Science', 'NaN', '3.60', '2024'],
#  ['1013', 'Mia', 'Math', '77', '', '2025'],
#  ['1014', 'Noah', 'Physics', '85', '3.25', '2027'],
#  ['1015', 'Olivia', 'Economics', '', '2.80', '2026']]

# %%
with open (file_path, mode ='r',encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        if a == 0:
            title = row
        a+=1
        if len(row) == 5 and a!=0:
            gooddata.append(row)
        else:
            baddata.append(row)
